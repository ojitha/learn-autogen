# %% [markdown]
# ## AutoGen Example
# Sudent Teacher conversation.

# %%
# %load_ext dotenv
# %dotenv ../../.env

# %%
import autogen
import os

llm_config = {
    "config_list": [
        {
            "model": "gpt-4.1-nano",
            "api_key": os.environ["OPENAI_API_KEY"],
        }
        , {
            "model": "gpt-4.1-mini",
            "api_key": os.environ["OPENAI_API_KEY"],
        }
    ]
}

# %%
from autogen import ConversableAgent

ConversableAgent(
    "chatbot",
    llm_config=llm_config["config_list"][model_no],
    code_execution_config=False,
    human_input_mode="NEVER" # no human interruptions
)

# %%
student = ConversableAgent(
    "student",
    system_message="""
    You are a high school student struggling with Algebra.
    You need to undersand quadratic equation.
    """,
    llm_config=llm_config["config_list"][0],
    code_execution_config=False,
    human_input_mode="NEVER" # no human interruptionsYou are a high school student struggling with Maths.

)

# %%
teacher = ConversableAgent(
    "teacher",
    system_message="""
    You are a high school teacher knowledgeable with Algebra.
    You have to teach students Algebra concepts such as quadratic equation.
    """,
    llm_config=llm_config["config_list"][1],
    code_execution_config=False,
    human_input_mode="NEVER" # no human interruptionsYou are a high school student struggling with Maths.

)

# %%
result = student.initiate_chat(
    teacher
    , message="Please teach me about quadratic equation."
    , max_turns=2
)
# Out:
# student (to teacher):
#
# Please teach me about quadratic equation.
#
# --------------------------------------------------------------------------------
# teacher (to student):
#
# Of course! Let's start with the basics of quadratic equations.
#
# ### What is a Quadratic Equation?
# A **quadratic equation** is a type of polynomial equation of degree 2. Its general form is:
#
# \[
# ax^2 + bx + c = 0
# \]
#
# where:
# - \( x \) is the variable,
# - \( a \), \( b \), and \( c \) are constants (with \( a \neq 0 \)).
#
# ### Why is it called a quadratic equation?
# Because the highest power of the variable \( x \) is 2 (from the term \( x^2 \)), and "quad" means square.
#
# ---
#
# ### How to solve a quadratic equation?
#
# There are several common methods:
#
# 1. **Factoring**
#    If the quadratic can be factored into the form \((x + m)(x + n) = 0\), then set each factor equal to zero:
#
#    \[
#    x + m = 0 \quad \text{or} \quad x + n = 0
#    \]
#
#    Then solve for \( x \).
#
# ...

# %%
import pprint
pprint.pprint(result.cost)
# Out:
# {'usage_excluding_cached_inference': {'gpt-4.1-mini-2025-04-14': {'completion_tokens': 8168,
#                                                                   'cost': 0.0298116,
#                                                                   'prompt_tokens': 41857,
#                                                                   'total_tokens': 50025},
#                                       'gpt-4.1-nano-2025-04-14': {'completion_tokens': 1006,
#                                                                   'cost': 0.004982599999999999,
#                                                                   'prompt_tokens': 45802,
#                                                                   'total_tokens': 46808},
#                                       'total_cost': 0.0347942},
#  'usage_including_cached_inference': {'gpt-4.1-mini-2025-04-14': {'completion_tokens': 8168,
#                                                                   'cost': 0.0298116,
# ...

# %%
pprint.pprint(result.chat_history)
# Out:
# [{'content': 'Please teach me about quadratic equation.',
#   'name': 'student',
#   'role': 'assistant'},
#  {'content': "Of course! Let's start with the basics of quadratic equations.\n"
#              '\n'
#              '### What is a Quadratic Equation?\n'
#              'A **quadratic equation** is a type of polynomial equation of '
#              'degree 2. Its general form is:\n'
#              '\n'
#              '\\[\n'
#              'ax^2 + bx + c = 0\n'
#              '\\]\n'
#              '\n'
#              'where:\n'
#              '- \\( x \\) is the variable,\n'
#              '- \\( a \\), \\( b \\), and \\( c \\) are constants (with \\( a '
#              '\\neq 0 \\)).\n'
#              '\n'
#              '### Why is it called a quadratic equation?\n'
#              'Because the highest power of the variable \\( x \\) is 2 (from '
#              'the term \\( x^2 \\)), and "quad" means square.\n'
#              '\n'
#              '---\n'
#              '\n'
# ...
